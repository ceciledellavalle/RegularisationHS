# %%
# General Import
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
# Local Import
from code.abelsolver import AbelSolver

# %% [markdown]
# Ici on a $q=1$ et $a=1$,
# donc la pente maximale est $q/(q+a) = 0.5$
# dès lors que $p \geq (q-a)/2 \geq 0$.

# %% [markdown]
# ### Off gaussian, a=1, p=1

# %%
exp1 = AbelSolver(a=1,p=1)

# %%
exp1.Slope(interval=(-3,-1),reg_param=(-9,-4),style='offgauss')
# Out:
# err=5.355e-02, inf=1.000e-09, sup=1.000e-04, reg=7.101e-08
# ...
# err=9.653e-02, inf=1.000e-09, sup=1.000e-04, reg=5.611e-07
# ...
# err=1.762e-01, inf=1.000e-09, sup=1.000e-04, reg=2.211e-06
# ...
# err=3.550e-01, inf=1.000e-09, sup=1.000e-04, reg=7.892e-06
# ...
# th. smax = 0.75 , s = 0.42 , R = 0.99941
# th. qmax =  3 , q = 0.72

# %% [markdown]
# Conclusion : since $q=1$, the expected slope for $a=1$ and $p=1$ is 0.5.
# We see that the result tends to a solution with $x'(0)=0$.

# %% [markdown]
# ### a=1, p=2

# %%
exp2 = AbelSolver(a=1,p=2)

# %%
exp2.Slope(interval=(-2.5,-1),style='offgauss',reg_param=(-11,-8))
# Out:
# err=8.911e-02, inf=1.000e-11, sup=1.000e-08, reg=3.327e-10
# ...
# err=1.217e-01, inf=1.000e-11, sup=1.000e-08, reg=1.443e-09
# ...
# err=1.864e-01, inf=1.000e-11, sup=1.000e-08, reg=5.152e-09
# ...
# err=3.856e-01, inf=1.000e-11, sup=1.000e-08, reg=1.000e-08
# ...
# th. smax = 0.8333333333333334 , s = 0.39 , R = 0.98990
# th. qmax =  5 , q = 0.63

# %% [markdown]
# Conclusion : since $q=1$, the expected slope for $a=1$ and $p=2$ is also 0.5.
# We see that the result tends to a solution with $x'(0)=0$.
# Here it is logical.
