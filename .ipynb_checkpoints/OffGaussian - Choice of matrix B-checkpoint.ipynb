# %%
# General Import
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
# Local Import
from code.abelsolver import AbelSolver

# %% [markdown]
# For $a=2/3$,
# the matrix $B=-Delta$ should not be enough to take into account high order of regularity.
# In particular, for $p=2$ the boundaries conditions changes.

# %%
exp0 = AbelSolver(a=1.5,p=2,methB='constant')
exp0.Slope(reg_param=(-16,-6),style='offgauss')
# Out:
# err=1.327e-01, inf=1.000e-16, sup=1.000e-06, reg=1.000e-10
# ==========================================
# err=1.310e-01, inf=1.000e-16, sup=1.000e-06, reg=1.000e-10
# ==========================================
# err=1.862e-01, inf=1.000e-16, sup=1.000e-06, reg=2.000e-10
# ==========================================
# err=6.191e-01, inf=1.000e-16, sup=1.000e-06, reg=5.001e-09
# ==========================================
# th. smax = 0.7857142857142857 , s = 0.17 , R = 0.82709
# th. qmax =  5.5 , q = 0.30

# %%
exp1 = AbelSolver(a=1.5,p=2,methB='explicit')
exp1.Slope(reg_param=(-16,-6),style='offgauss')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-9ce7db629f99> in <module>
# ----> 1 exp1 = AbelSolver(a=1.5,p=2,methB='explicit')
#       2 exp1.Slope(reg_param=(-16,-6),style='offgauss')
#
# ~/Documents/RegularisationHS/code/abelsolver.py in __init__(self, a, p, nx, kernel, npt, methT, methB, resol, folder)
#      82         self.folder = folder
#      83         # operators
# ---> 84         self.T, self.tTT, self.tDD = MatrixGen(a,p,nx,kernel,methT,methB)
#      85
#      86     # Compute and export slope
#
# ~/Documents/RegularisationHS/code/myfunc.py in MatrixGen(a, p, nx, kernel, method1, method2)
#     149     # ==================================================
#     150     #
# --> 151     return T,tTT,tDD
#     152
#     153 def Conjugate_grad(A,b,x=None,eps=1e-16):
#
# UnboundLocalError: local variable 'tDD' referenced before assignment
