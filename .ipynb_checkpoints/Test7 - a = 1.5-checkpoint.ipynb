# %%
#global import
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.linalg import inv,pinvh,eig,eigh
from scipy.stats import linregress
# %matplotlib inline
# local import
from code.slope import Slope
from code.slope import DataGen
from code.slope import Solver
from code.slope import MatrixGen

# %%
# a= 1.5 ; p=1
T,tTT,tDD = MatrixGen(a=1.5,p=1,nx=100,method1='trapeze',method2='inv')
x,y,yd = DataGen(T,noise = 0.05)
x,xout = Solver(x,yd,(T,tTT,tDD),reg_inf=10**-11,reg_sup=10**-6, export=True,a=1.5,p=1)
# Out:
# err=5.023e-01, inf=1.000e-11, sup=1.000e-06, reg=7.955e-08
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-911052bc73c3> in <module>
#       2 T,tTT,tDD = MatrixGen(a=1.5,p=1,nx=100,method1='trapeze',method2='inv')
#       3 x,y,yd = DataGen(T,noise = 0.05)
# ----> 4 x,xout = Solver(x,yd,(T,tTT,tDD),reg_inf=10**-11,reg_sup=10**-6, export=True)
#
# ~/Documents/HilbertScale/RegularisationHS/code/slope.py in Solver(x, y, Matrix, reg_inf, reg_sup, resol, export)
#     244     # export
#     245     if export:
# --> 246         Export(t,xadp,"gauss_pred{}{}".format(a,p))
#     247         print("gauss_pred{}{}".format(a,p))
#     248     return x, xadp
#
# NameError: name 'a' is not defined

# %%
#Slope(a=3,p=1,nx=100,npt=20,methT='trapeze',methB='inv',export=True,resol='no')
