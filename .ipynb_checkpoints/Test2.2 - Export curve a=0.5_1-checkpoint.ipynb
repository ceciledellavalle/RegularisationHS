# %%
#global import
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.linalg import inv,pinvh,eig,eigh
from scipy.stats import linregress
# %matplotlib inline
# local import
from code.slope import Slope
from code.slope import DataGen
from code.slope import Solver
from code.slope import MatrixGen

# %% [markdown]
# # a=1

# %%
T,tTT,tDD = MatrixGen(a=1,p=1,nx=100)
x,y,yd = DataGen(T,noise = 0.01)
x,xout = Solver(x,yd,(T,tTT,tDD),reg_sup=10**-6)
# Out:
# err=1.278e-01, inf=1.000e-10, sup=1.000e-06, reg=2.277e-07

# %%
Slope()

# %% [markdown]
# # a=0.5, p=1

# %%
T,tTT,tDD = MatrixGen(a=0.5,p=1,nx=100)
x,y,yd = DataGen(T,noise = 0.01)
x,xout = Solver(x,yd,(T,tTT,tDD),reg_sup=10**-6)
# Out:
# err=1.246e-01, inf=1.000e-10, sup=1.000e-06, reg=1.000e-06
# sup= 1e-06 , reg= 1e-06
# Wrong regularization parameter, too low

# %%
#Slope(a=0.5,export=True)
# Out:
# sup= 1.1753064387831193e-10 , reg= 1.1753064387831193e-10
# Wrong regularization parameter, too low
# ==========================================
# delta=3.372e-04, inf=1.175e-14, sup=1.175e-10, reg=1.175e-10
# ==========================================
# sup= 1.6906194155711357e-10 , reg= 1.6906194155711357e-10
# Wrong regularization parameter, too low
# ==========================================
# sup= 2.4318713094653874e-10 , reg= 2.4318713094653874e-10
# Wrong regularization parameter, too low
# ==========================================
# sup= 3.4981250134304847e-10 , reg= 3.4981250134304847e-10
# Wrong regularization parameter, too low
# ==========================================
# sup= 5.031877534785415e-10 , reg= 5.031877534785415e-10
# Wrong regularization parameter, too low
# ==========================================
# sup= 7.238103677789236e-10 , reg= 7.238103677789236e-10
# Wrong regularization parameter, too low
# ==========================================
# delta=2.077e-03, inf=7.238e-14, sup=7.238e-10, reg=7.238e-10
# ==========================================
# sup= 1.0411649426730406e-09 , reg= 1.0411649426730406e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 1.497663595477081e-09 , reg= 1.497663595477081e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 2.154314031606507e-09 , reg= 2.154314031606507e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 3.098872778100933e-09 , reg= 3.098872778100933e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 4.4575732014769696e-09 , reg= 4.4575732014769696e-09
# Wrong regularization parameter, too low
# ==========================================
# delta=1.279e-02, inf=4.458e-13, sup=4.458e-09, reg=4.458e-09
# ==========================================
# sup= 6.4119956736986295e-09 , reg= 6.4119956736986295e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 9.223334460532745e-09 , reg= 9.223334460532745e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 1.3267304424393078e-08 , reg= 1.3267304424393078e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 1.908435256714665e-08 , reg= 1.908435256714665e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 2.7451884818254453e-08 , reg= 2.7451884818254453e-08
# Wrong regularization parameter, too low
# ==========================================
# delta=7.877e-02, inf=2.745e-12, sup=2.745e-08, reg=2.745e-08
# ==========================================
# sup= 3.948816065010393e-08 , reg= 3.948816065010393e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 5.6801740275827284e-08 , reg= 5.6801740275827284e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 8.17064569543086e-08 , reg= 8.17064569543086e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 1.1753064387830596e-07 , reg= 1.1753064387830596e-07
# Wrong regularization parameter, too low
# ==========================================
# th. smax = 0.8333333333333334 , s = 0.85 , R = 0.99970
# th. qmax =  2.5 , q = 2.81

# %% [markdown]
# # ANNEXE

# %%
# # power subdunction
# nx=5
# a=3
# p=1
# def power(M,r) :
#     D,P = eigh(M)
#     D = np.diag(D**r)
#     return P.dot(D).dot(np.transpose(P))
# # initialisation
# dx   = 1/nx
# # Matrice opérateur
# T = np.zeros((nx,nx))
# coeff = 1/a*1/(a+1)*1/nx**a
# for i in range(nx):
#     for j in range(nx):#lower half
#         if i<j:
#             T[i,j] = coeff*((j-i+1)**(a+1)\
#                            +(j-i-1)**(a+1)\
#                            -2*(j-i)**(a+1))
#         elif i==j:#diagonal
#             T[i,j] = coeff
# T   = np.transpose(T)
# tTT = np.transpose(T).dot(T)
# # Matrice regularisation
# if a<=1:
#     D   = power(tTT,-p/(2*a))
#     tDD = np.transpose(D).dot(D)
# else:
#     B   = 2*np.diag(np.ones(nx)) \
#               - np.diag(np.ones(nx-1),1)\
#               - np.diag(np.ones(nx-1),-1)
#     B[0,0]= 1
#     D   = power(B,p/2)
#     tDD = np.transpose(D).dot(D)
