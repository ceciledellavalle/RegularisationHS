# %%
#global import
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.linalg import inv,pinvh,eig,eigh
from scipy.stats import linregress
# %matplotlib inline
# local import
from code.slope import Slope
from code.slope import DataGen
from code.slope import Solver
from code.slope import MatrixGen

# %% [markdown]
# # a=1

# %%
T,tTT,tDD = MatrixGen(a=1,p=1,nx=100)
x,y,yd = DataGen(T,noise = 0.01)
x,xout = Solver(x,yd,(T,tTT,tDD),reg_sup=10**-6)
# Out:
# err=1.302e-01, inf=1.000e-10, sup=1.000e-06, reg=2.413e-07

# %%
Slope()
# Out:
# sup= 8.796648219580631e-10 , reg= 8.796648219580631e-10
# Wrong regularization parameter, too low
# ==========================================
# delta=1.196e-04, inf=8.797e-12, sup=8.797e-10, reg=8.797e-10
# ==========================================
# sup= 1.265353764876248e-09 , reg= 1.265353764876248e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 1.8201479817306203e-09 , reg= 1.8201479817306203e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 2.6181916609874096e-09 , reg= 2.6181916609874096e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 3.7661375022628316e-09 , reg= 3.7661375022628316e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 5.417400069406055e-09 , reg= 5.417400069406055e-09
# Wrong regularization parameter, too low
# ==========================================
# delta=7.363e-04, inf=5.417e-11, sup=5.417e-09, reg=5.417e-09
# ==========================================
# sup= 7.792658524646792e-09 , reg= 7.792658524646792e-09
# Wrong regularization parameter, too low
# ==========================================
# sup= 1.1209348784242067e-08 , reg= 1.1209348784242067e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 1.6124086506470417e-08 , reg= 1.6124086506470417e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 2.3193690433972976e-08 , reg= 2.3193690433972976e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 3.3362961413727105e-08 , reg= 3.3362961413727105e-08
# Wrong regularization parameter, too low
# ==========================================
# delta=4.535e-03, inf=3.336e-10, sup=3.336e-08, reg=3.336e-08
# ==========================================
# sup= 4.7990948118521356e-08 , reg= 4.7990948118521356e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 6.903257395990605e-08 , reg= 6.903257395990605e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 9.92998983008367e-08 , reg= 9.92998983008367e-08
# Wrong regularization parameter, too low
# ==========================================
# sup= 1.428379276178149e-07 , reg= 1.428379276178149e-07
# Wrong regularization parameter, too low
# ==========================================
# sup= 2.054652010250872e-07 , reg= 2.054652010250872e-07
# Wrong regularization parameter, too low
# ==========================================
# delta=2.793e-02, inf=2.055e-09, sup=2.055e-07, reg=2.055e-07
# ==========================================
# sup= 2.955513954615388e-07 , reg= 2.955513954615388e-07
# Wrong regularization parameter, too low
# ==========================================
# sup= 4.251358717849133e-07 , reg= 4.251358717849133e-07
# Wrong regularization parameter, too low
# ==========================================
# sup= 6.11536647276087e-07 , reg= 6.11536647276087e-07
# Wrong regularization parameter, too low
# ==========================================
# sup= 8.796648219580992e-07 , reg= 8.796648219580992e-07
# Wrong regularization parameter, too low
# ==========================================
# th. smax = 0.75 , s = 0.66 , R = 0.99977
# th. qmax =  3 , q = 1.95

# %% [markdown]
# # a=0.5, p=1

# %%
T,tTT,tDD = MatrixGen(a=0.5,p=1,nx=100)
x,y,yd = DataGen(T,noise = 0.01)
x,xout = Solver(x,yd,(T,tTT,tDD),reg_sup=10**-6)
# Out:
# err=9.684e-02, inf=1.000e-10, sup=1.000e-06, reg=1.000e-06
# sup= 1e-06 , reg= 1e-06
# Wrong regularization parameter, too low

# %%
#Slope(a=0.5,export=True)

# %% [markdown]
# # ANNEXE

# %%
# # power subdunction
# nx=5
# a=3
# p=1
# def power(M,r) :
#     D,P = eigh(M)
#     D = np.diag(D**r)
#     return P.dot(D).dot(np.transpose(P))
# # initialisation
# dx   = 1/nx
# # Matrice opérateur
# T = np.zeros((nx,nx))
# coeff = 1/a*1/(a+1)*1/nx**a
# for i in range(nx):
#     for j in range(nx):#lower half
#         if i<j:
#             T[i,j] = coeff*((j-i+1)**(a+1)\
#                            +(j-i-1)**(a+1)\
#                            -2*(j-i)**(a+1))
#         elif i==j:#diagonal
#             T[i,j] = coeff
# T   = np.transpose(T)
# tTT = np.transpose(T).dot(T)
# # Matrice regularisation
# if a<=1:
#     D   = power(tTT,-p/(2*a))
#     tDD = np.transpose(D).dot(D)
# else:
#     B   = 2*np.diag(np.ones(nx)) \
#               - np.diag(np.ones(nx-1),1)\
#               - np.diag(np.ones(nx-1),-1)
#     B[0,0]= 1
#     D   = power(B,p/2)
#     tDD = np.transpose(D).dot(D)
