# %%
# General Import
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
# Local Import
from code.abelsolver import AbelSolver

# %% [markdown]
# ### Off gaussian, a=1, p=1

# %%
exp1 = AbelSolver(a=1,p=1)

# %%
x,y,yd = exp1.DataGen(noise=10**-4,style='offgauss',export=True)

# %%
xadp = exp1.Solver(x,yd,reg_inf=10**-50,reg_sup=10**-5,export=True)
# Out:
# err=2.352e-02, inf=1.000e-50, sup=1.000e-05, reg=3.000e-09

# %%
exp1.Slope(style='gauss')
# Out:
# err=5.110e-03, inf=1.000e-16, sup=1.000e-06, reg=7.701e-09
# ==========================================
# err=2.237e-02, inf=1.000e-16, sup=1.000e-06, reg=3.150e-08
# ==========================================
# err=1.096e-01, inf=1.000e-16, sup=1.000e-06, reg=1.383e-07
# ==========================================
# noise=0.000e+00 sup= 1e-06 , reg= 1e-06
# Wrong regularization parameter, too low
# ==========================================
# noise=8.267e-02 sup= 1e-06 , reg= 1e-06
# Wrong regularization parameter, too low
# ==========================================
# err=4.822e-01, inf=1.000e-16, sup=1.000e-06, reg=1.000e-06
# ==========================================
# noise=0.000e+00 sup= 1e-06 , reg= 1e-06
# Wrong regularization parameter, too low
# ==========================================
# th. smax = 0.75 , s = 0.71 , R = 0.99974
# th. qmax =  3 , q = 2.43

# %% [markdown]
# ### a=1, p=2

# %%
exp2 = AbelSolver(a=1,p=2)

# %%
exp2.Slope(style='gauss')
# Out:
# noise=1.189e-04 inf= 1e-16 , reg= 1e-16
# Wrong regularization parameter, too high
# ==========================================
# err=1.754e-02, inf=1.000e-16, sup=1.000e-06, reg=1.000e-16
# ==========================================
# noise=0.000e+00 inf= 1e-16 , reg= 1e-16
# Wrong regularization parameter, too high
# ==========================================
# err=3.397e-02, inf=1.000e-16, sup=1.000e-06, reg=1.000e-10
# ==========================================
# err=9.809e-02, inf=1.000e-16, sup=1.000e-06, reg=1.000e-10
# ==========================================
# err=3.956e-01, inf=1.000e-16, sup=1.000e-06, reg=3.300e-09
# ==========================================
# th. smax = 0.8333333333333334 , s = 0.38 , R = 0.94990
# th. qmax =  5 , q = 0.61
