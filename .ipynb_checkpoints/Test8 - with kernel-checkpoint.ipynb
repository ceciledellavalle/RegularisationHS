# %%
#global import
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.linalg import inv,pinvh,eig,eigh
from scipy.stats import linregress
# %matplotlib inline
# local import
from code.slope import Slope
from code.slope import DataGen
from code.slope import Solver
from code.slope import MatrixGen

# %%
# a=0.5 ; p=1 ; kernel
T,tTT,tDD = MatrixGen(a=0.5,p=1,kernel=True,nx=100,method1='',method2='explicit')
x,y,yd = DataGen(T,noise = 0.05,export=True,a=0.5,kern='kernel')
x,xout = Solver(x,yd,(T,tTT,tDD),reg_inf=10**-5,reg_sup=10**-2,export=True,a=0.5,p=1,kern='kernel')
# Out:
# err=1.864e-01, inf=1.000e-05, sup=1.000e-02, reg=2.029e-03

# %%
Slope(a=0.5,p=1,nx=100,kernel=True,npt=20,methT='trapeze',methB='explicit',export=False,resol='no')
# Out:
# delta=3.055e-03, inf=1.000e-06, sup=1.000e-02, reg=1.980e-05
# ...
# delta=1.881e-02, inf=1.000e-06, sup=1.000e-02, reg=7.669e-05
# ...
# delta=1.159e-01, inf=1.000e-06, sup=1.000e-02, reg=3.006e-04
# ...
# delta=7.135e-01, inf=1.000e-06, sup=1.000e-02, reg=1.281e-03
# ...
# th. smax = 0.8333333333333334 , s = 0.73 , R = 1.00000
# th. qmax =  2.5 , q = 1.37
