# %%
# comparaison
#global import
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.linalg import inv,pinvh,eig,eigh
from scipy.stats import linregress
# %matplotlib inline
# local import
from code.slope import Slope
from code.slope import DataGen
from code.slope import Solver
from code.slope import MatrixGen

# %%
# a=1 ; p=1
T,tTT,tDD = MatrixGen(a=1,p=1,nx=100,method1='trapeze')
x,y,yd = DataGen(T,noise = 0.05)

# %%
# PYTHON OFFICIAL CG
xcg,xoutcg = Solver(x,yd,(T,tTT,tDD),reg_inf=10**-10,reg_sup=10**-5,resol='cg')
# Out:
# err=3.485e-01, inf=1.000e-10, sup=1.000e-05, reg=9.856e-07

# %%
xmy,xoutmy = Solver(x,yd,(T,tTT,tDD),reg_inf=10**-10,reg_sup=10**-5,resol='mycg')
# Out:
# err=3.485e-01, inf=1.000e-10, sup=1.000e-05, reg=9.856e-07

# %%
x,xout = Solver(x,yd,(T,tTT,tDD),reg_inf=10**-10,reg_sup=10**-5,resol='mycg')
# Out:
# err=3.485e-01, inf=1.000e-10, sup=1.000e-05, reg=9.856e-07

# %%
np.linalg.norm(xoutmy-xout)
# Out:
# 0.0

# %%
np.linalg.norm(xoutcg-xout)
# Out:
# 0.0
