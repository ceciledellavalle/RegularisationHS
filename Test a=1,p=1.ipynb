# %%
# General Import
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
# Local Import
from code.abelsolver import AbelSolver

# %% [markdown]
# ### Off gaussian, a=1, p=1

# %%
exp1 = AbelSolver(a=1,p=1)

# %%
x,y,yd = exp1.DataGen(noise=0.05,style='offgauss',export=True)

# %%
# xadp = exp1.Solver(x,yd,reg_inf=10**-6,reg_sup=10**-5,export=True)

# %%
exp1.Slope(style='offgauss')
# Out:
# noise=2.491e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# err=3.989e-02, inf=1.000e-11, sup=1.000e-06, reg=1.000e-11
# ...
# noise=2.491e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# err=1.860e-01, inf=1.000e-11, sup=1.000e-06, reg=8.811e-09
# ...
# err=3.499e-01, inf=1.000e-11, sup=1.000e-06, reg=4.791e-08
# ...
# err=8.984e-01, inf=1.000e-11, sup=1.000e-06, reg=2.434e-07
# ...
# th. smax = 0.75 , s = 0.34 , R = 0.99312
# th. qmax =  3 , q = 0.52

# %% [markdown]
# ### a=1, p=2

# %%
exp2 = AbelSolver(a=1,p=2)

# %%
exp2.Slope(style='offgauss')
# Out:
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# err=5.523e-01, inf=1.000e-11, sup=1.000e-06, reg=1.000e-11
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# err=5.536e-01, inf=1.000e-11, sup=1.000e-06, reg=1.000e-11
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
# noise=9.988e-01 inf= 1e-11 , reg= 1e-11
# Wrong regularization parameter, too high
# ...
